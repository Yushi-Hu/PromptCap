# %%
import torch
from promptcap import PromptCap

model = PromptCap("vqascore/promptcap-coco-vqa")  # also support OFA checkpoints. e.g. "OFA-Sys/ofa-large"

if torch.cuda.is_available():
  model.cuda()

prompt = "please describe this image according to the given question: what piece of clothing is this boy putting on?"
image = "glove_boy.jpeg"

print(model.caption(prompt, image))
# Out:
# vqascore/promptcap-coco-vqa
# <super: <class 'OFATokenizer'>, <OFATokenizer object>>
# Downloading:   0%|          | 0.00/2.45G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import torch
#       2 from promptcap import PromptCap
# ----> 4 model = PromptCap("vqascore/promptcap-coco-vqa")  # also support OFA checkpoints. e.g. "OFA-Sys/ofa-large"
#       6 if torch.cuda.is_available():
#       7   model.cuda()
#
# File ~/Documents/GitHub/PromptCap/promptcap/promptcap.py:13, in PromptCap.__init__(self, ckpt)
#      11 super().__init__()
#      12 self.tokenizer = OFATokenizer.from_pretrained(ckpt)
# ---> 13 self.model = OFAModel.from_pretrained(ckpt, use_cache=True)
#      14 self.model.eval()
#      16 mean, std = [0.5, 0.5, 0.5], [0.5, 0.5, 0.5]
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/transformers/modeling_utils.py:2137, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2122 try:
#    2123     # Load from URL or cache if already cached
#    2124     cached_file_kwargs = dict(
#    2125         cache_dir=cache_dir,
#    2126         force_download=force_download,
#    (...)
#    2135         _commit_hash=commit_hash,
#    2136     )
# -> 2137     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    2139     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    2140     # result when internet is up, the repo and revision exist, but the file does not.
#    2141     if resolved_archive_file is None and filename == SAFE_WEIGHTS_NAME:
#    2142         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/transformers/utils/hub.py:409, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     406 user_agent = http_user_agent(user_agent)
#     407 try:
#     408     # Load from URL or cache if already cached
# --> 409     resolved_file = hf_hub_download(
#     410         path_or_repo_id,
#     411         filename,
#     412         subfolder=None if len(subfolder) == 0 else subfolder,
#     413         revision=revision,
#     414         cache_dir=cache_dir,
#     415         user_agent=user_agent,
#     416         force_download=force_download,
#     417         proxies=proxies,
#     418         resume_download=resume_download,
#     419         use_auth_token=use_auth_token,
#     420         local_files_only=local_files_only,
#     421     )
#     423 except RepositoryNotFoundError:
#     424     raise EnvironmentError(
#     425         f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     426         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to "
#     427         "pass a token having permission to this repo with `use_auth_token` or log in with "
#     428         "`huggingface-cli login` and pass `use_auth_token=True`."
#     429     )
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:124, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     119 if check_use_auth_token:
#     120     kwargs = smoothly_deprecate_use_auth_token(
#     121         fn_name=fn.__name__, has_token=has_token, kwargs=kwargs
#     122     )
# --> 124 return fn(*args, **kwargs)
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/huggingface_hub/file_download.py:1242, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1239 with temp_file_manager() as temp_file:
#    1240     logger.info("downloading %s to %s", url, temp_file.name)
# -> 1242     http_get(
#    1243         url_to_download,
#    1244         temp_file,
#    1245         proxies=proxies,
#    1246         resume_size=resume_size,
#    1247         headers=headers,
#    1248     )
#    1250 logger.info("storing %s in cache at %s", url, blob_path)
#    1251 _chmod_and_replace(temp_file.name, blob_path)
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/huggingface_hub/file_download.py:495, in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries)
#     486 total = resume_size + int(content_length) if content_length is not None else None
#     487 progress = tqdm(
#     488     unit="B",
#     489     unit_scale=True,
#    (...)
#     493     disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     494 )
# --> 495 for chunk in r.iter_content(chunk_size=1024):
#     496     if chunk:  # filter out keep-alive new chunks
#     497         progress.update(len(chunk))
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~/miniforge3/envs/pt113/lib/python3.10/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniforge3/envs/pt113/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File ~/miniforge3/envs/pt113/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniforge3/envs/pt113/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/pt113/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
